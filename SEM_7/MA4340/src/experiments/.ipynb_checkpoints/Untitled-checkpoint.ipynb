# %% [markdown]
# # Monte Carlo Option Pricing
# ## Experiments
# ### Raj Patil : CS18BTECH11039

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Num simulations

# %%
df_call = pd.read_csv("num_sim_call.csv").drop(0)
df_put = pd.read_csv("num_sim_put.csv").drop(0)

# %%
x = range(100,10000,100)

# %%
plt.figure(figsize= (15,10))
plt.plot(x,df_call['ste'],label="call_ste")
plt.plot(x,df_put['ste'],label="put_ste")
plt.legend()
plt.xlabel("Number of simulations")
plt.ylabel("Standard Error")
plt.title("Error with Number of Simulations")
plt.savefig("num_sim.png")

# %%
df_call
# Out:
#    Unnamed: 0  call_price       std       ste  black_scholes_call
# 1         100    3.120237  7.010201  0.701020            3.346875
# 2         200    3.401806  6.592142  0.466135            3.346875
# 3         300    3.514532  6.460212  0.372981            3.346875
# 4         400    2.955225  5.969237  0.298462            3.346875
# 5         500    2.817332  6.293378  0.281448            3.346875
# ..        ...         ...       ...       ...                 ...
# 95       9500    3.330054  6.614334  0.067862            3.346875
# 96       9600    3.292764  6.645324  0.067824            3.346875
# 97       9700    3.363452  6.719123  0.068222            3.346875
# 98       9800    3.498733  6.784003  0.068529            3.346875
# 99       9900    3.257200  6.496442  0.065292            3.346875
#
# [99 rows x 5 columns]

# %%
plt.figure(figsize= (15,10))

plt.plot(x,df_call['call_price'],label="call_price")
plt.plot(x,df_call['black_scholes_call'],"g--",label="black_scholes_call")

plt.legend()
plt.xlabel("Number of simulations")
plt.ylabel("Option Price")
plt.title("Call Price Evolution with Number of Simulations")
plt.savefig("num_sim.png")

# %%
plt.figure(figsize= (15,10))

plt.plot(x,df_put['put_price'],label="put_price")
plt.plot(x,df_put['black_scholes_put'],"g--",label="black_scholes_put")


plt.legend()
plt.xlabel("Number of simulations")
plt.ylabel("Option Price")
plt.title("Put Price Evolution with Number of Simulations")
plt.savefig("num_sim.png")

# %% [markdown]
# ## Granularity

# %%
df_call = pd.read_csv("granularity_call.csv").drop(0)
df_put = pd.read_csv("granularity_put.csv").drop(0)

# %%
plt.figure(figsize= (15,10))
plt.plot(x,df_call['ste'],label="call_ste")
plt.plot(x,df_put['ste'],label="put_ste")
plt.legend()
plt.xlabel("Number of simulations")
plt.ylabel("Standard Error")
plt.title("Error with Number of Simulations")
plt.savefig("num_sim.png")
